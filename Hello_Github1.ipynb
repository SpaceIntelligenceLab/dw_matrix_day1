# %%
print("Hello Github version 2")
# Out:
# Hello Github version 2

# %%
print("Nice to see you again")
# Out:
# Nice to see you again

# %%
a = 2
b = 3
c = input("Please enter a number:\n")
c = int(c)
d = a + b + c
print(f'You enterd {c} and calculation result is {d}')
# Out:
# Please enter a number:
# 135
# You enterd 135 and calculation result is 140

# %%
list1 = [a,b,c,d]
print(list1)
# Out:
# [2, 3, 135, 140]

# %%
a = input("Please enter number a:\n")
a = int(a)

b = input("Please enter number b:\n")
b = int(b)

c = input("Please enter number c:\n")
c = int(c)

d = input("Please enter number d:\n")
d = int(d)

result = a + b + c + d
print(f'You enterd {a}, {b}, {c}, {d} and calculation result is {result}')
# Out:
# Please enter number a:
# 12
# Please enter number b:
# 150
# Please enter number c:
# 280
# Please enter number d:
# 17
# You enterd 12, 150, 280, 17 and calculation result is 459

# %%
a = input("Please enter number a:\n")
a = int(a)

b = input("Please enter number b:\n")
b = int(b)

c = input("Please enter number c:\n")
c = int(c)

d = input("Please enter number d:\n")
d = int(d)

result = a * b + c - d
print(f'You enterd {a}, {b}, {c}, {d} and calculation a * b + c - d result is {result}')
# Out:
# Please enter number a:
# 10
# Please enter number b:
# 12
# Please enter number c:
# 13
# Please enter number d:
# 5
# You enterd 10, 12, 13, 5 and calculation a * b + c - d result is 128
